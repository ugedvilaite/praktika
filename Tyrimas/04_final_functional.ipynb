# %% [markdown]
#   # 04 — Final Functional Classification Notebook
#
#
#
#   This notebook builds the final, thesis-ready comparison across the
#
#   functional and interpretable models that are actually relevant for the project.
#
#
#
#   It does four things:
#
#
#
#   1. Loads the sampled Gaia XP spectra as functional data.
#
#   2. Reruns the selected distance-based models on the shared repeated CV splits.
#
#   3. Reruns functional linear models directly on the spectra:
#
#      - functional logistic regression
#
#      - functional linear SVM
#
#   4. Imports existing summaries for:
#
#      - FPCA / FPLS models
#
#
#
#
#   Main model families:
#
#   - distance-based functional classifiers
#
#   - FPCA / FPLS classifiers
#
#   - functional linear classifiers
#
#
#
#
#   Main evaluation metrics:
#
#   - PR-AUC
#
#   - ROC-AUC
#
#   - Sensitivity
#
#   - Precision
#
#   - Specificity
#
#   - Accuracy
#
#   - F1
#
#   - Youden J
#
#
#
#   Outputs (results/final_functional/):
#
#   - final_functional_distance_fold_metrics.csv
#
#   - final_functional_distance_summary.csv
#
#   - final_functional_linear_fold_metrics.csv
#
#   - final_functional_linear_summary.csv
#
#   - final_functional_final_df.csv
#
#   - final_functional_rank_by_f1.csv
#
#   - final_functional_rank_by_pr_auc.csv
#
#   - final_functional_pretty_table.csv
#
#   - final_functional_best_by_family.csv
#
#   - final_functional_interpretability_payload.npz
#
#   - final_functional_nearest_neighbour_table.csv

# %%
from __future__ import annotations

import json
import warnings
from datetime import datetime
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from sklearn.cross_decomposition import PLSRegression
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.metrics import (
    accuracy_score,
    average_precision_score,
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
    roc_auc_score,
)
from sklearn.metrics.pairwise import pairwise_distances
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.svm import LinearSVC

warnings.filterwarnings("ignore")

RANDOM_STATE = 42
np.random.seed(RANDOM_STATE)

# %% [markdown]
#   ## 1. Configuration

# %%
BASE_DIR = Path.cwd() / "og_data"

OUT_DIR = Path.cwd() / "results" / "final_functional"
OUT_DIR.mkdir(parents=True, exist_ok=True)

NOTEBOOK_NAME = "04_final_functional"
TIMESTAMP = datetime.now().strftime("%Y%m%d_%H%M")

SMOKE = False

# Distance-model configuration
DISTANCE_K = 5
DISTANCE_MODELS = [
    {"model_name": "weighted kNN", "distance": "euclidean", "weighted": True},
    {"model_name": "weighted kNN", "distance": "cosine", "weighted": True},
    {"model_name": "weighted kNN", "distance": "seuclidean", "weighted": True},
    {"model_name": "weighted kNN", "distance": "correlation", "weighted": True},
    {"model_name": "centroid", "distance": "euclidean", "weighted": False},
    {"model_name": "centroid", "distance": "cosine", "weighted": False},
    {"model_name": "centroid", "distance": "seuclidean", "weighted": False},
    {"model_name": "centroid", "distance": "correlation", "weighted": False},
]

# Functional linear models
LINEAR_MODELS = [
    {
        "family": "Functional linear",
        "method": "Functional logistic regression (L2)",
        "kind": "logreg_l2",
    },
    {
        "family": "Functional linear",
        "method": "Functional logistic regression (L1)",
        "kind": "logreg_l1",
    },
    {
        "family": "Functional linear",
        "method": "Functional linear SVM",
        "kind": "linear_svm",
    },
]

INNER_CV = 5
CS_GRID = np.logspace(-4, 4, 10)

RESULTS_PARENT = BASE_DIR / "results"
FILE_FPCA_FPLS_SUMMARY = None

# %% [markdown]
#   ## 2. File helpers

# %%
def find_first_existing(paths: list[Path]) -> Path | None:
    for p in paths:
        if p.exists():
            return p
    return None


def find_latest(pattern: str, folder: Path) -> Path | None:
    matches = sorted(folder.glob(pattern))
    return matches[-1] if matches else None


def split_sort_key(k: str) -> tuple[int, int]:
    rep = int(k.split("_")[0].replace("rep", ""))
    fold = int(k.split("_")[1].replace("fold", ""))
    return (rep, fold)


def ms(mean, std):
    if pd.isna(mean):
        return np.nan
    return f"{mean:.4f} ± {0.0 if pd.isna(std) else std:.4f}"


def normalize_scores_train_ref(scores_te: np.ndarray, scores_tr: np.ndarray) -> np.ndarray:
    lo = float(np.min(scores_tr))
    hi = float(np.max(scores_tr))
    if hi == lo:
        return np.full_like(scores_te, 0.5, dtype=np.float64)
    out = (scores_te - lo) / (hi - lo)
    return np.clip(out, 0.0, 1.0).astype(np.float64)


def pick_youden_threshold(y_true: np.ndarray, y_prob: np.ndarray, grid_size: int = 200) -> float:
    thresholds = np.linspace(0, 1, grid_size)
    best_j = -1.0
    best_thr = 0.5

    for thr in thresholds:
        y_pred = (y_prob >= thr).astype(np.int64)
        tn, fp, fn, tp = confusion_matrix(y_true, y_pred, labels=[0, 1]).ravel()
        sens = tp / (tp + fn) if (tp + fn) else 0.0
        spec = tn / (tn + fp) if (tn + fp) else 0.0
        j = sens + spec - 1.0
        if j > best_j:
            best_j = j
            best_thr = float(thr)

    return best_thr


def fold_metrics(
    y_true_te: np.ndarray,
    y_score_te: np.ndarray,
    y_true_tr: np.ndarray,
    y_score_tr: np.ndarray,
) -> dict:
    out = {"pr_auc": average_precision_score(y_true_te, y_score_te)}

    try:
        out["roc_auc"] = float(roc_auc_score(y_true_te, y_score_te))
    except ValueError:
        out["roc_auc"] = np.nan

    prob_tr = normalize_scores_train_ref(y_score_tr, y_score_tr)
    prob_te = normalize_scores_train_ref(y_score_te, y_score_tr)
    thr = pick_youden_threshold(y_true_tr, prob_tr)
    y_pred = (prob_te >= thr).astype(np.int64)

    out["youden_threshold"] = thr
    out["sensitivity"] = recall_score(y_true_te, y_pred, pos_label=1, zero_division=0)
    out["precision"] = precision_score(y_true_te, y_pred, pos_label=1, zero_division=0)
    out["specificity"] = recall_score(y_true_te, y_pred, pos_label=0, zero_division=0)
    out["accuracy"] = accuracy_score(y_true_te, y_pred)
    out["f1"] = f1_score(y_true_te, y_pred, pos_label=1, zero_division=0)

    tn, fp, fn, tp = confusion_matrix(y_true_te, y_pred, labels=[0, 1]).ravel()
    sens = tp / (tp + fn) if (tp + fn) else 0.0
    spec = tn / (tn + fp) if (tn + fp) else 0.0
    out["youden_j"] = sens + spec - 1.0
    return out


def summarise_run(df_run: pd.DataFrame, group_cols: list[str]) -> pd.DataFrame:
    metric_cols = [
        "pr_auc", "roc_auc", "sensitivity", "precision", "specificity",
        "accuracy", "f1", "youden_j", "youden_threshold"
    ]

    agg_dict = {}
    for m in metric_cols:
        agg_dict[f"{m}_mean"] = pd.NamedAgg(column=m, aggfunc="mean")
        agg_dict[f"{m}_std"] = pd.NamedAgg(column=m, aggfunc="std")

    return (
        df_run.groupby(group_cols)
        .agg(**agg_dict)
        .reset_index()
    )

# %% [markdown]
#   ## 3. Locate core files

# %%
LABEL_FILE = find_first_existing([
    BASE_DIR / "og_xp.csv",
])
SPLIT_FILE = find_first_existing([
    BASE_DIR / "splits_rskf.json",
])
SAMPLED_FILE = find_first_existing([
    BASE_DIR / "xp_sampled_spectra.csv",
])

if LABEL_FILE is None:
    raise FileNotFoundError("Missing og_xp.csv")
if SPLIT_FILE is None:
    raise FileNotFoundError("Missing splits_rskf.json")
if SAMPLED_FILE is None:
    raise FileNotFoundError("Missing xp_sampled_spectra.csv")

FILE_FPCA_FPLS_SUMMARY = find_latest(
    "03_fpca_vs_fpls_classifier_summary_*.csv", OUT_DIR
)

print("LABEL_FILE:", LABEL_FILE)
print("SPLIT_FILE:", SPLIT_FILE)
print("SAMPLED_FILE:", SAMPLED_FILE)
print("FPCA/FPLS summary:", FILE_FPCA_FPLS_SUMMARY)
# Out:
# LABEL_FILE: c:\Users\Lenovo\Documents\VDA\Bakalauras\astroflow_project\og_xp.csv
# SPLIT_FILE: c:\Users\Lenovo\Documents\VDA\Bakalauras\astroflow_project\splits_rskf.json
# SAMPLED_FILE: c:\Users\Lenovo\Documents\VDA\Bakalauras\astroflow_project\xp_sampled_spectra.csv
# FPCA/FPLS summary: None

# %% [markdown]
#   ## 4. Load labels, sampled spectra, and repeated splits

# %%
df_labels = pd.read_csv(LABEL_FILE)
if "source_id" not in df_labels.columns or "y" not in df_labels.columns:
    raise ValueError("og_xp.csv must contain source_id and y")

df_spec = pd.read_csv(SAMPLED_FILE)
if "source_id" not in df_spec.columns:
    raise ValueError("xp_sampled_spectra.csv must contain source_id")

wl_cols = [c for c in df_spec.columns if c.startswith("wl_")]
if len(wl_cols) == 0:
    raise ValueError("No sampled spectrum columns found (expected wl_*)")

wavelengths = np.array([float(c.split("_")[1]) for c in wl_cols], dtype=np.float64)

df_m = df_labels[["source_id", "y"]].merge(
    df_spec[["source_id"] + wl_cols],
    on="source_id",
    how="inner",
    validate="one_to_one",
)

X_raw = df_m[wl_cols].to_numpy(dtype=np.float64)
y = df_m["y"].to_numpy(dtype=np.int64)

row_norm = np.linalg.norm(X_raw, axis=1, keepdims=True)
X = np.divide(X_raw, row_norm, out=np.zeros_like(X_raw), where=row_norm > 1e-20)

with open(SPLIT_FILE) as f:
    splits = json.load(f)

split_names = sorted(splits.keys(), key=split_sort_key)
if SMOKE:
    split_names = [k for k in split_names if k.startswith("rep0_")]

print("Merged rows:", len(df_m))
print("X shape:", X.shape)
print("Binary fraction:", round((y == 1).mean(), 4))
print("Number of splits:", len(split_names))
print("Wavelength range:", wavelengths.min(), "to", wavelengths.max())
# Out:
# Merged rows: 2815
# X shape: (2815, 343)
# Binary fraction: 0.1982
# Number of splits: 50
# Wavelength range: 336.0 to 1020.0

# %% [markdown]
#   ## 5. Distance-model helpers

# %%
def train_distance_params(X_tr: np.ndarray, distance_name: str) -> dict:
    params = {"distance": distance_name}

    if distance_name == "seuclidean":
        V = np.var(X_tr, axis=0, ddof=1)
        V = np.where(V <= 1e-12, 1e-12, V)
        params["V"] = V

    elif distance_name == "correlation":
        params["mu"] = np.mean(X_tr, axis=0)
        params["sigma"] = np.std(X_tr, axis=0) + 1e-12

    return params


def pairwise_distance_matrix(X_a: np.ndarray, X_b: np.ndarray, params: dict) -> np.ndarray:
    dname = params["distance"]

    if dname == "euclidean":
        return pairwise_distances(X_a, X_b, metric="euclidean")

    if dname == "cosine":
        return pairwise_distances(X_a, X_b, metric="cosine")

    if dname == "seuclidean":
        return pairwise_distances(X_a, X_b, metric="seuclidean", V=params["V"])

    if dname == "correlation":
        return pairwise_distances(X_a, X_b, metric="correlation")

    raise ValueError(f"Unsupported distance: {dname}")


def knn_scores_from_distances(
    D: np.ndarray,
    y_ref: np.ndarray,
    k: int,
    weighted: bool = True,
    exclude_self: bool = False,
) -> np.ndarray:
    D = D.copy()

    if exclude_self and D.shape[0] == D.shape[1]:
        np.fill_diagonal(D, np.inf)

    nn_idx = np.argsort(D, axis=1)[:, :k]
    nn_d = np.take_along_axis(D, nn_idx, axis=1)
    nn_y = y_ref[nn_idx]

    if weighted:
        w = 1.0 / np.maximum(nn_d, 1e-12)
        score = (w * nn_y).sum(axis=1) / w.sum(axis=1)
    else:
        score = nn_y.mean(axis=1)

    return score.astype(np.float64)


def centroid_scores_from_distances(
    X_ref: np.ndarray,
    y_ref: np.ndarray,
    X_query: np.ndarray,
    params: dict,
) -> np.ndarray:
    c0 = X_ref[y_ref == 0].mean(axis=0, keepdims=True)
    c1 = X_ref[y_ref == 1].mean(axis=0, keepdims=True)

    d0 = pairwise_distance_matrix(X_query, c0, params).ravel()
    d1 = pairwise_distance_matrix(X_query, c1, params).ravel()

    s0 = 1.0 / np.maximum(d0, 1e-12)
    s1 = 1.0 / np.maximum(d1, 1e-12)
    score = s1 / (s0 + s1)
    return score.astype(np.float64)


def run_distance_model_one_split(
    X: np.ndarray,
    y: np.ndarray,
    train_idx: np.ndarray,
    test_idx: np.ndarray,
    model_cfg: dict,
) -> dict:
    X_tr = X[train_idx]
    X_te = X[test_idx]
    y_tr = y[train_idx]
    y_te = y[test_idx]

    params = train_distance_params(X_tr, model_cfg["distance"])

    if model_cfg["model_name"] == "weighted kNN":
        D_tr = pairwise_distance_matrix(X_tr, X_tr, params)
        D_te = pairwise_distance_matrix(X_te, X_tr, params)

        score_tr = knn_scores_from_distances(
            D_tr, y_tr, k=DISTANCE_K, weighted=model_cfg["weighted"], exclude_self=True
        )
        score_te = knn_scores_from_distances(
            D_te, y_tr, k=DISTANCE_K, weighted=model_cfg["weighted"], exclude_self=False
        )

    elif model_cfg["model_name"] == "centroid":
        score_tr = centroid_scores_from_distances(X_tr, y_tr, X_tr, params)
        score_te = centroid_scores_from_distances(X_tr, y_tr, X_te, params)

    else:
        raise ValueError(f"Unsupported model: {model_cfg['model_name']}")

    metrics = fold_metrics(y_te, score_te, y_tr, score_tr)

    out = {
        "family": "Distance-based functional",
        "model_name": model_cfg["model_name"],
        "distance": model_cfg["distance"],
        "method": f"{model_cfg['model_name']} + {model_cfg['distance']}",
    }
    out.update(metrics)
    return out

# %% [markdown]
#   ## 6. Rerun distance-based functional models

# %%
distance_records = []

for sname in split_names:
    print(f"Current Fold: {sname}")
    tr_idx = np.array(splits[sname]["train"], dtype=int)
    te_idx = np.array(splits[sname]["test"], dtype=int)

    for cfg in DISTANCE_MODELS:
        print(f"  -> Running model: {cfg['model_name']} + {cfg['distance']}")
        rec = run_distance_model_one_split(X, y, tr_idx, te_idx, cfg)
        rec["split"] = sname
        distance_records.append(rec)

df_distance_fold = pd.DataFrame(distance_records)
df_distance_summary = summarise_run(
    df_distance_fold,
    ["family", "model_name", "distance", "method"],
)

print("Distance fold metrics:", df_distance_fold.shape)
print("Distance summary:", df_distance_summary.shape)
print(df_distance_summary.sort_values(["f1_mean", "pr_auc_mean"], ascending=False).head(10))
# Out:
# Current Fold: rep0_fold0
#   -> Running model: weighted kNN + euclidean
#   -> Running model: weighted kNN + cosine
#   -> Running model: weighted kNN + seuclidean
#   -> Running model: weighted kNN + correlation
#   -> Running model: centroid + euclidean
#   -> Running model: centroid + cosine
#   -> Running model: centroid + seuclidean
#   -> Running model: centroid + correlation
# Current Fold: rep0_fold1
#   -> Running model: weighted kNN + euclidean
#   -> Running model: weighted kNN + cosine
#   -> Running model: weighted kNN + seuclidean
#   -> Running model: weighted kNN + correlation
#   -> Running model: centroid + euclidean
#   -> Running model: centroid + cosine
#   -> Running model: centroid + seuclidean
#   -> Running model: centroid + correlation
# Current Fold: rep0_fold2
#   -> Running model: weighted kNN + euclidean
#   -> Running model: weighted kNN + cosine
#   -> Running model: weighted kNN + seuclidean
#   -> Running model: weighted kNN + correlation
#   -> Running model: centroid + euclidean
#   -> Running model: centroid + cosine
#   -> Running model: centroid + seuclidean
#   -> Running model: centroid + correlation
# Current Fold: rep0_fold3
#   -> Running model: weighted kNN + euclidean
#   -> Running model: weighted kNN + cosine
#   -> Running model: weighted kNN + seuclidean
#   -> Running model: weighted kNN + correlation
#   -> Running model: centroid + euclidean
#   -> Running model: centroid + cosine
#   -> Running model: centroid + seuclidean
#   -> Running model: centroid + correlation
# Current Fold: rep0_fold4
#   -> Running model: weighted kNN + euclidean
#   -> Running model: weighted kNN + cosine
#   -> Running model: weighted kNN + seuclidean
#   -> Running model: weighted kNN + correlation
#   -> Running model: centroid + euclidean
#   -> Running model: centroid + cosine
#   -> Running model: centroid + seuclidean
#   -> Running model: centroid + correlation
# Current Fold: rep1_fold0
#   -> Running model: weighted kNN + euclidean
#   -> Running model: weighted kNN + cosine
#   -> Running model: weighted kNN + seuclidean
#   -> Running model: weighted kNN + correlation
#   -> Running model: centroid + euclidean
#   -> Running model: centroid + cosine
#   -> Running model: centroid + seuclidean
#   -> Running model: centroid + correlation
# Current Fold: rep1_fold1
#   -> Running model: weighted kNN + euclidean
#   -> Running model: weighted kNN + cosine
#   -> Running model: weighted kNN + seuclidean
#   -> Running model: weighted kNN + correlation
#   -> Running model: centroid + euclidean
#   -> Running model: centroid + cosine
#   -> Running model: centroid + seuclidean
#   -> Running model: centroid + correlation
# Current Fold: rep1_fold2
#   -> Running model: weighted kNN + euclidean
#   -> Running model: weighted kNN + cosine
#   -> Running model: weighted kNN + seuclidean
#   -> Running model: weighted kNN + correlation
#   -> Running model: centroid + euclidean
#   -> Running model: centroid + cosine
#   -> Running model: centroid + seuclidean
#   -> Running model: centroid + correlation
# Current Fold: rep1_fold3
#   -> Running model: weighted kNN + euclidean
#   -> Running model: weighted kNN + cosine
#   -> Running model: weighted kNN + seuclidean
#   -> Running model: weighted kNN + correlation
#   -> Running model: centroid + euclidean
#   -> Running model: centroid + cosine
#   -> Running model: centroid + seuclidean
#   -> Running model: centroid + correlation
# Current Fold: rep1_fold4
#   -> Running model: weighted kNN + euclidean
#   -> Running model: weighted kNN + cosine
#   -> Running model: weighted kNN + seuclidean
#   -> Running model: weighted kNN + correlation
#   -> Running model: centroid + euclidean
#   -> Running model: centroid + cosine
#   -> Running model: centroid + seuclidean
#   -> Running model: centroid + correlation
# Current Fold: rep2_fold0
#   -> Running model: weighted kNN + euclidean
#   -> Running model: weighted kNN + cosine
#   -> Running model: weighted kNN + seuclidean
#   -> Running model: weighted kNN + correlation
#   -> Running model: centroid + euclidean
#   -> Running model: centroid + cosine
#   -> Running model: centroid + seuclidean
#   -> Running model: centroid + correlation
# Current Fold: rep2_fold1
#   -> Running model: weighted kNN + euclidean
#   -> Running model: weighted kNN + cosine
#   -> Running model: weighted kNN + seuclidean
#   -> Running model: weighted kNN + correlation
#   -> Running model: centroid + euclidean
#   -> Running model: centroid + cosine
#   -> Running model: centroid + seuclidean
#   -> Running model: centroid + correlation
# Current Fold: rep2_fold2
#   -> Running model: weighted kNN + euclidean
#   -> Running model: weighted kNN + cosine
#   -> Running model: weighted kNN + seuclidean
#   -> Running model: weighted kNN + correlation
#   -> Running model: centroid + euclidean
#   -> Running model: centroid + cosine
#   -> Running model: centroid + seuclidean
#   -> Running model: centroid + correlation
# Current Fold: rep2_fold3
#   -> Running model: weighted kNN + euclidean
#   -> Running model: weighted kNN + cosine
#   -> Running model: weighted kNN + seuclidean
#   -> Running model: weighted kNN + correlation
#   -> Running model: centroid + euclidean
#   -> Running model: centroid + cosine
#   -> Running model: centroid + seuclidean
#   -> Running model: centroid + correlation
# Current Fold: rep2_fold4
#   -> Running model: weighted kNN + euclidean
#   -> Running model: weighted kNN + cosine
#   -> Running model: weighted kNN + seuclidean
#   -> Running model: weighted kNN + correlation
#   -> Running model: centroid + euclidean
#   -> Running model: centroid + cosine
#   -> Running model: centroid + seuclidean
#   -> Running model: centroid + correlation
# Current Fold: rep3_fold0
#   -> Running model: weighted kNN + euclidean
#   -> Running model: weighted kNN + cosine
#   -> Running model: weighted kNN + seuclidean
#   -> Running model: weighted kNN + correlation
#   -> Running model: centroid + euclidean
#   -> Running model: centroid + cosine
#   -> Running model: centroid + seuclidean
#   -> Running model: centroid + correlation
# Current Fold: rep3_fold1
#   -> Running model: weighted kNN + euclidean
#   -> Running model: weighted kNN + cosine
#   -> Running model: weighted kNN + seuclidean
#   -> Running model: weighted kNN + correlation
#   -> Running model: centroid + euclidean
#   -> Running model: centroid + cosine
#   -> Running model: centroid + seuclidean
#   -> Running model: centroid + correlation
# Current Fold: rep3_fold2
#   -> Running model: weighted kNN + euclidean
#   -> Running model: weighted kNN + cosine
#   -> Running model: weighted kNN + seuclidean
#   -> Running model: weighted kNN + correlation
#   -> Running model: centroid + euclidean
#   -> Running model: centroid + cosine
#   -> Running model: centroid + seuclidean
#   -> Running model: centroid + correlation
# Current Fold: rep3_fold3
#   -> Running model: weighted kNN + euclidean
#   -> Running model: weighted kNN + cosine
#   -> Running model: weighted kNN + seuclidean
#   -> Running model: weighted kNN + correlation
#   -> Running model: centroid + euclidean
#   -> Running model: centroid + cosine
#   -> Running model: centroid + seuclidean
#   -> Running model: centroid + correlation
# Current Fold: rep3_fold4
#   -> Running model: weighted kNN + euclidean
#   -> Running model: weighted kNN + cosine
#   -> Running model: weighted kNN + seuclidean
#   -> Running model: weighted kNN + correlation
#   -> Running model: centroid + euclidean
#   -> Running model: centroid + cosine
#   -> Running model: centroid + seuclidean
#   -> Running model: centroid + correlation
# Current Fold: rep4_fold0
#   -> Running model: weighted kNN + euclidean
#   -> Running model: weighted kNN + cosine
#   -> Running model: weighted kNN + seuclidean
#   -> Running model: weighted kNN + correlation
#   -> Running model: centroid + euclidean
#   -> Running model: centroid + cosine
#   -> Running model: centroid + seuclidean
#   -> Running model: centroid + correlation
# Current Fold: rep4_fold1
#   -> Running model: weighted kNN + euclidean
#   -> Running model: weighted kNN + cosine
#   -> Running model: weighted kNN + seuclidean
#   -> Running model: weighted kNN + correlation
#   -> Running model: centroid + euclidean
#   -> Running model: centroid + cosine
#   -> Running model: centroid + seuclidean
#   -> Running model: centroid + correlation
# Current Fold: rep4_fold2
#   -> Running model: weighted kNN + euclidean
#   -> Running model: weighted kNN + cosine
#   -> Running model: weighted kNN + seuclidean
#   -> Running model: weighted kNN + correlation
#   -> Running model: centroid + euclidean
#   -> Running model: centroid + cosine
#   -> Running model: centroid + seuclidean
#   -> Running model: centroid + correlation
# Current Fold: rep4_fold3
#   -> Running model: weighted kNN + euclidean
#   -> Running model: weighted kNN + cosine
#   -> Running model: weighted kNN + seuclidean
#   -> Running model: weighted kNN + correlation
#   -> Running model: centroid + euclidean
#   -> Running model: centroid + cosine
#   -> Running model: centroid + seuclidean
#   -> Running model: centroid + correlation
# Current Fold: rep4_fold4
#   -> Running model: weighted kNN + euclidean
#   -> Running model: weighted kNN + cosine
#   -> Running model: weighted kNN + seuclidean
#   -> Running model: weighted kNN + correlation
#   -> Running model: centroid + euclidean
#   -> Running model: centroid + cosine
#   -> Running model: centroid + seuclidean
#   -> Running model: centroid + correlation
# Current Fold: rep5_fold0
#   -> Running model: weighted kNN + euclidean
#   -> Running model: weighted kNN + cosine
#   -> Running model: weighted kNN + seuclidean
#   -> Running model: weighted kNN + correlation
#   -> Running model: centroid + euclidean
#   -> Running model: centroid + cosine
#   -> Running model: centroid + seuclidean
#   -> Running model: centroid + correlation
# Current Fold: rep5_fold1
#   -> Running model: weighted kNN + euclidean
#   -> Running model: weighted kNN + cosine
#   -> Running model: weighted kNN + seuclidean
#   -> Running model: weighted kNN + correlation
#   -> Running model: centroid + euclidean
#   -> Running model: centroid + cosine
#   -> Running model: centroid + seuclidean
#   -> Running model: centroid + correlation
# Current Fold: rep5_fold2
#   -> Running model: weighted kNN + euclidean
#   -> Running model: weighted kNN + cosine
#   -> Running model: weighted kNN + seuclidean
#   -> Running model: weighted kNN + correlation
#   -> Running model: centroid + euclidean
#   -> Running model: centroid + cosine
#   -> Running model: centroid + seuclidean
#   -> Running model: centroid + correlation
# Current Fold: rep5_fold3
#   -> Running model: weighted kNN + euclidean
#   -> Running model: weighted kNN + cosine
#   -> Running model: weighted kNN + seuclidean
#   -> Running model: weighted kNN + correlation
#   -> Running model: centroid + euclidean
#   -> Running model: centroid + cosine
#   -> Running model: centroid + seuclidean
#   -> Running model: centroid + correlation
# Current Fold: rep5_fold4
#   -> Running model: weighted kNN + euclidean
#   -> Running model: weighted kNN + cosine
#   -> Running model: weighted kNN + seuclidean
#   -> Running model: weighted kNN + correlation
#   -> Running model: centroid + euclidean
#   -> Running model: centroid + cosine
#   -> Running model: centroid + seuclidean
#   -> Running model: centroid + correlation
# Current Fold: rep6_fold0
#   -> Running model: weighted kNN + euclidean
#   -> Running model: weighted kNN + cosine
#   -> Running model: weighted kNN + seuclidean
#   -> Running model: weighted kNN + correlation
#   -> Running model: centroid + euclidean
#   -> Running model: centroid + cosine
#   -> Running model: centroid + seuclidean
#   -> Running model: centroid + correlation
# Current Fold: rep6_fold1
#   -> Running model: weighted kNN + euclidean
#   -> Running model: weighted kNN + cosine
#   -> Running model: weighted kNN + seuclidean
#   -> Running model: weighted kNN + correlation
#   -> Running model: centroid + euclidean
#   -> Running model: centroid + cosine
#   -> Running model: centroid + seuclidean
#   -> Running model: centroid + correlation
# Current Fold: rep6_fold2
#   -> Running model: weighted kNN + euclidean
#   -> Running model: weighted kNN + cosine
#   -> Running model: weighted kNN + seuclidean
#   -> Running model: weighted kNN + correlation
#   -> Running model: centroid + euclidean
#   -> Running model: centroid + cosine
#   -> Running model: centroid + seuclidean
#   -> Running model: centroid + correlation
# Current Fold: rep6_fold3
#   -> Running model: weighted kNN + euclidean
#   -> Running model: weighted kNN + cosine
#   -> Running model: weighted kNN + seuclidean
#   -> Running model: weighted kNN + correlation
#   -> Running model: centroid + euclidean
#   -> Running model: centroid + cosine
#   -> Running model: centroid + seuclidean
#   -> Running model: centroid + correlation
# Current Fold: rep6_fold4
#   -> Running model: weighted kNN + euclidean
#   -> Running model: weighted kNN + cosine
#   -> Running model: weighted kNN + seuclidean
#   -> Running model: weighted kNN + correlation
#   -> Running model: centroid + euclidean
#   -> Running model: centroid + cosine
#   -> Running model: centroid + seuclidean
#   -> Running model: centroid + correlation
# Current Fold: rep7_fold0
#   -> Running model: weighted kNN + euclidean
#   -> Running model: weighted kNN + cosine
#   -> Running model: weighted kNN + seuclidean
#   -> Running model: weighted kNN + correlation
#   -> Running model: centroid + euclidean
#   -> Running model: centroid + cosine
#   -> Running model: centroid + seuclidean
#   -> Running model: centroid + correlation
# Current Fold: rep7_fold1
#   -> Running model: weighted kNN + euclidean
#   -> Running model: weighted kNN + cosine
#   -> Running model: weighted kNN + seuclidean
#   -> Running model: weighted kNN + correlation
#   -> Running model: centroid + euclidean
#   -> Running model: centroid + cosine
#   -> Running model: centroid + seuclidean
#   -> Running model: centroid + correlation
# Current Fold: rep7_fold2
#   -> Running model: weighted kNN + euclidean
#   -> Running model: weighted kNN + cosine
#   -> Running model: weighted kNN + seuclidean
#   -> Running model: weighted kNN + correlation
#   -> Running model: centroid + euclidean
#   -> Running model: centroid + cosine
#   -> Running model: centroid + seuclidean
#   -> Running model: centroid + correlation
# Current Fold: rep7_fold3
#   -> Running model: weighted kNN + euclidean
#   -> Running model: weighted kNN + cosine
#   -> Running model: weighted kNN + seuclidean
#   -> Running model: weighted kNN + correlation
#   -> Running model: centroid + euclidean
#   -> Running model: centroid + cosine
#   -> Running model: centroid + seuclidean
#   -> Running model: centroid + correlation
# Current Fold: rep7_fold4
#   -> Running model: weighted kNN + euclidean
#   -> Running model: weighted kNN + cosine
#   -> Running model: weighted kNN + seuclidean
#   -> Running model: weighted kNN + correlation
#   -> Running model: centroid + euclidean
#   -> Running model: centroid + cosine
#   -> Running model: centroid + seuclidean
#   -> Running model: centroid + correlation
# Current Fold: rep8_fold0
#   -> Running model: weighted kNN + euclidean
#   -> Running model: weighted kNN + cosine
#   -> Running model: weighted kNN + seuclidean
#   -> Running model: weighted kNN + correlation
#   -> Running model: centroid + euclidean
#   -> Running model: centroid + cosine
#   -> Running model: centroid + seuclidean
#   -> Running model: centroid + correlation
# Current Fold: rep8_fold1
#   -> Running model: weighted kNN + euclidean
#   -> Running model: weighted kNN + cosine
#   -> Running model: weighted kNN + seuclidean
#   -> Running model: weighted kNN + correlation
#   -> Running model: centroid + euclidean
#   -> Running model: centroid + cosine
#   -> Running model: centroid + seuclidean
#   -> Running model: centroid + correlation
# Current Fold: rep8_fold2
#   -> Running model: weighted kNN + euclidean
#   -> Running model: weighted kNN + cosine
#   -> Running model: weighted kNN + seuclidean
#   -> Running model: weighted kNN + correlation
#   -> Running model: centroid + euclidean
#   -> Running model: centroid + cosine
#   -> Running model: centroid + seuclidean
#   -> Running model: centroid + correlation
# Current Fold: rep8_fold3
#   -> Running model: weighted kNN + euclidean
#   -> Running model: weighted kNN + cosine
#   -> Running model: weighted kNN + seuclidean
#   -> Running model: weighted kNN + correlation
#   -> Running model: centroid + euclidean
#   -> Running model: centroid + cosine
#   -> Running model: centroid + seuclidean
#   -> Running model: centroid + correlation
# Current Fold: rep8_fold4
#   -> Running model: weighted kNN + euclidean
#   -> Running model: weighted kNN + cosine
#   -> Running model: weighted kNN + seuclidean
#   -> Running model: weighted kNN + correlation
#   -> Running model: centroid + euclidean
#   -> Running model: centroid + cosine
#   -> Running model: centroid + seuclidean
#   -> Running model: centroid + correlation
# Current Fold: rep9_fold0
#   -> Running model: weighted kNN + euclidean
#   -> Running model: weighted kNN + cosine
#   -> Running model: weighted kNN + seuclidean
#   -> Running model: weighted kNN + correlation
#   -> Running model: centroid + euclidean
#   -> Running model: centroid + cosine
#   -> Running model: centroid + seuclidean
#   -> Running model: centroid + correlation
# Current Fold: rep9_fold1
#   -> Running model: weighted kNN + euclidean
#   -> Running model: weighted kNN + cosine
#   -> Running model: weighted kNN + seuclidean
#   -> Running model: weighted kNN + correlation
#   -> Running model: centroid + euclidean
#   -> Running model: centroid + cosine
#   -> Running model: centroid + seuclidean
#   -> Running model: centroid + correlation
# Current Fold: rep9_fold2
#   -> Running model: weighted kNN + euclidean
#   -> Running model: weighted kNN + cosine
#   -> Running model: weighted kNN + seuclidean
#   -> Running model: weighted kNN + correlation
#   -> Running model: centroid + euclidean
#   -> Running model: centroid + cosine
#   -> Running model: centroid + seuclidean
#   -> Running model: centroid + correlation
# Current Fold: rep9_fold3
#   -> Running model: weighted kNN + euclidean
#   -> Running model: weighted kNN + cosine
#   -> Running model: weighted kNN + seuclidean
#   -> Running model: weighted kNN + correlation
#   -> Running model: centroid + euclidean
#   -> Running model: centroid + cosine
#   -> Running model: centroid + seuclidean
#   -> Running model: centroid + correlation
# Current Fold: rep9_fold4
#   -> Running model: weighted kNN + euclidean
#   -> Running model: weighted kNN + cosine
#   -> Running model: weighted kNN + seuclidean
#   -> Running model: weighted kNN + correlation
#   -> Running model: centroid + euclidean
#   -> Running model: centroid + cosine
#   -> Running model: centroid + seuclidean
#   -> Running model: centroid + correlation
# Distance fold metrics: (400, 14)
# Distance summary: (8, 22)
#                       family    model_name     distance  \
# 7  Distance-based functional  weighted kNN   seuclidean
# 6  Distance-based functional  weighted kNN    euclidean
# 5  Distance-based functional  weighted kNN       cosine
# 3  Distance-based functional      centroid   seuclidean
# 1  Distance-based functional      centroid       cosine
# 2  Distance-based functional      centroid    euclidean
# 4  Distance-based functional  weighted kNN  correlation
# 0  Distance-based functional      centroid  correlation
#
#                        method  pr_auc_mean  pr_auc_std  roc_auc_mean  \
# 7   weighted kNN + seuclidean     0.808304    0.035406      0.891048
# 6    weighted kNN + euclidean     0.736810    0.040613      0.854622
# 5       weighted kNN + cosine     0.736709    0.040452      0.854638
# 3       centroid + seuclidean     0.573751    0.041169      0.799785
# 1           centroid + cosine     0.539304    0.043801      0.777023
# 2        centroid + euclidean     0.540099    0.043804      0.777215
# 4  weighted kNN + correlation     0.545041    0.043815      0.728922
# 0      centroid + correlation     0.372718    0.044441      0.677382
#
#    roc_auc_std  sensitivity_mean  sensitivity_std  ...  specificity_mean  \
# 7     0.020077          0.776499         0.040170  ...          0.942927
# 6     0.024432          0.685487         0.041446  ...          0.931499
# 5     0.024412          0.685845         0.042392  ...          0.929462
# 3     0.024732          0.734780         0.037229  ...          0.768679
# 1     0.025532          0.720800         0.036209  ...          0.727871
# 2     0.025559          0.719723         0.036629  ...          0.727871
# 4     0.024417          0.484649         0.060223  ...          0.886980
# 0     0.031218          0.709334         0.046406  ...          0.542851
#
#    specificity_std  accuracy_mean  accuracy_std   f1_mean    f1_std  \
# 7         0.014496       0.909947      0.011811  0.773768  0.027378
# 6         0.016621       0.882735      0.014043  0.698724  0.031923
# 5         0.018436       0.881172      0.014569  0.696108  0.031373
# 3         0.024407       0.761954      0.020622  0.550740  0.028079
# 1         0.025907       0.726465      0.022095  0.511395  0.027299
# 2         0.026036       0.726252      0.022256  0.510830  0.027600
# 4         0.045307       0.807211      0.031104  0.499961  0.041552
# 0         0.041612       0.575844      0.029476  0.398912  0.019379
#
#    youden_j_mean  youden_j_std  youden_threshold_mean  youden_threshold_std
# 7       0.719426      0.038035               0.282111              0.076271
# 6       0.616987      0.041082               0.305829              0.075045
# 5       0.615307      0.040626               0.313367              0.059862
# 3       0.503458      0.043671               0.337186              0.008689
# 1       0.448671      0.044905               0.310854              0.007598
# 2       0.447594      0.045437               0.354070              0.013206
# 4       0.371629      0.050565               0.251859              0.044097
# 0       0.252185      0.042450               0.399196              0.030392
#
# [8 rows x 22 columns]

# %% [markdown]
#   ## 7. Functional linear model helpers

# %%
def mean_inner_cv_roc_auc_at_best_c(clf: LogisticRegressionCV) -> float:
    sc = clf.scores_
    if sc is None:
        return np.nan

    if isinstance(sc, dict):
        arr = np.asarray(next(iter(sc.values())))
    elif hasattr(sc, "ndim") and sc.ndim == 3:
        arr = sc[0]
    else:
        arr = np.asarray(sc)

    c_grid = np.asarray(clf.Cs_)
    best_c = float(clf.C_[0])
    j = int(np.argmin(np.abs(c_grid - best_c)))
    return float(np.mean(arr[:, j]))


def run_linear_model_one_split(
    X: np.ndarray,
    y: np.ndarray,
    train_idx: np.ndarray,
    test_idx: np.ndarray,
    kind: str,
) -> tuple[dict, np.ndarray]:
    X_tr = X[train_idx]
    X_te = X[test_idx]
    y_tr = y[train_idx]
    y_te = y[test_idx]

    scaler = StandardScaler()
    X_tr_s = scaler.fit_transform(X_tr)
    X_te_s = scaler.transform(X_te)

    if kind == "logreg_l2":
        model = LogisticRegressionCV(
            Cs=CS_GRID,
            cv=StratifiedKFold(n_splits=INNER_CV, shuffle=True, random_state=RANDOM_STATE),
            penalty="l2",
            solver="lbfgs",
            class_weight="balanced",
            scoring="roc_auc",
            max_iter=2000,
            n_jobs=-1,
            random_state=RANDOM_STATE,
        )
        model.fit(X_tr_s, y_tr)
        score_tr = model.predict_proba(X_tr_s)[:, 1]
        score_te = model.predict_proba(X_te_s)[:, 1]
        coef = model.coef_[0].copy()
        extra = {
            "best_C": float(model.C_[0]),
            "best_cv_roc_auc": mean_inner_cv_roc_auc_at_best_c(model),
            "n_nonzero_coefs": int(X.shape[1]),
        }

    elif kind == "logreg_l1":
        model = LogisticRegressionCV(
            Cs=CS_GRID,
            cv=StratifiedKFold(n_splits=INNER_CV, shuffle=True, random_state=RANDOM_STATE),
            penalty="l1",
            solver="liblinear",
            class_weight="balanced",
            scoring="roc_auc",
            max_iter=4000,
            n_jobs=-1,
            random_state=RANDOM_STATE,
        )
        model.fit(X_tr_s, y_tr)
        score_tr = model.predict_proba(X_tr_s)[:, 1]
        score_te = model.predict_proba(X_te_s)[:, 1]
        coef = model.coef_[0].copy()
        extra = {
            "best_C": float(model.C_[0]),
            "best_cv_roc_auc": mean_inner_cv_roc_auc_at_best_c(model),
            "n_nonzero_coefs": int(np.sum(np.abs(coef) > 1e-6)),
        }

    elif kind == "linear_svm":
        inner_cv = StratifiedKFold(n_splits=INNER_CV, shuffle=True, random_state=RANDOM_STATE)
        c_scores = []

        for C in CS_GRID:
            fold_scores = []
            for inner_tr, inner_va in inner_cv.split(X_tr_s, y_tr):
                clf = LinearSVC(
                    C=C,
                    class_weight="balanced",
                    max_iter=10000,
                    random_state=RANDOM_STATE,
                )
                clf.fit(X_tr_s[inner_tr], y_tr[inner_tr])
                va_score = clf.decision_function(X_tr_s[inner_va])
                try:
                    auc = roc_auc_score(y_tr[inner_va], va_score)
                except ValueError:
                    auc = np.nan
                fold_scores.append(auc)

            c_scores.append(np.nanmean(fold_scores))

        best_i = int(np.nanargmax(c_scores))
        best_c = float(CS_GRID[best_i])

        model = LinearSVC(
            C=best_c,
            class_weight="balanced",
            max_iter=10000,
            random_state=RANDOM_STATE,
        )
        model.fit(X_tr_s, y_tr)
        score_tr = model.decision_function(X_tr_s)
        score_te = model.decision_function(X_te_s)
        coef = model.coef_[0].copy()
        extra = {
            "best_C": best_c,
            "best_cv_roc_auc": float(c_scores[best_i]),
            "n_nonzero_coefs": int(np.sum(np.abs(coef) > 1e-12)),
        }

    else:
        raise ValueError(f"Unsupported kind: {kind}")

    metrics = fold_metrics(y_te, score_te, y_tr, score_tr)
    metrics.update(extra)
    return metrics, coef

# %% [markdown]
#   ## 8. Rerun functional logistic regression and linear SVM

# %%
linear_records = []
coef_store = {cfg["method"]: [] for cfg in LINEAR_MODELS}

for sname in split_names:
    print(f"Current Fold: {sname}")
    tr_idx = np.array(splits[sname]["train"], dtype=int)
    te_idx = np.array(splits[sname]["test"], dtype=int)

    for cfg in LINEAR_MODELS:
        print(f"  -> Running method: {cfg['method']}")
        met, coef = run_linear_model_one_split(X, y, tr_idx, te_idx, cfg["kind"])

        row = {
            "split": sname,
            "family": cfg["family"],
            "method": cfg["method"],
        }
        row.update(met)
        linear_records.append(row)
        coef_store[cfg["method"]].append(coef)

df_linear_fold = pd.DataFrame(linear_records)
df_linear_summary = summarise_run(
    df_linear_fold,
    ["family", "method"],
)

print("\nProcessing complete.")
print("Linear fold metrics:", df_linear_fold.shape)
print("Linear summary:", df_linear_summary.shape)
print(df_linear_summary.sort_values(["f1_mean", "pr_auc_mean"], ascending=False))
# Out:
# Current Fold: rep0_fold0
#   -> Running method: Functional logistic regression (L2)
#   -> Running method: Functional logistic regression (L1)
#   -> Running method: Functional linear SVM
# Current Fold: rep0_fold1
#   -> Running method: Functional logistic regression (L2)
#   -> Running method: Functional logistic regression (L1)
#   -> Running method: Functional linear SVM
# Current Fold: rep0_fold2
#   -> Running method: Functional logistic regression (L2)
#   -> Running method: Functional logistic regression (L1)
#   -> Running method: Functional linear SVM
# Current Fold: rep0_fold3
#   -> Running method: Functional logistic regression (L2)
#   -> Running method: Functional logistic regression (L1)
#   -> Running method: Functional linear SVM
# Current Fold: rep0_fold4
#   -> Running method: Functional logistic regression (L2)
#   -> Running method: Functional logistic regression (L1)
#   -> Running method: Functional linear SVM
# Current Fold: rep1_fold0
#   -> Running method: Functional logistic regression (L2)
#   -> Running method: Functional logistic regression (L1)
#   -> Running method: Functional linear SVM
# Current Fold: rep1_fold1
#   -> Running method: Functional logistic regression (L2)
#   -> Running method: Functional logistic regression (L1)
#   -> Running method: Functional linear SVM
# Current Fold: rep1_fold2
#   -> Running method: Functional logistic regression (L2)
#   -> Running method: Functional logistic regression (L1)
#   -> Running method: Functional linear SVM
# Current Fold: rep1_fold3
#   -> Running method: Functional logistic regression (L2)
#   -> Running method: Functional logistic regression (L1)
#   -> Running method: Functional linear SVM
# Current Fold: rep1_fold4
#   -> Running method: Functional logistic regression (L2)
#   -> Running method: Functional logistic regression (L1)
#   -> Running method: Functional linear SVM
# Current Fold: rep2_fold0
#   -> Running method: Functional logistic regression (L2)
#   -> Running method: Functional logistic regression (L1)
#   -> Running method: Functional linear SVM
# Current Fold: rep2_fold1
#   -> Running method: Functional logistic regression (L2)
#   -> Running method: Functional logistic regression (L1)
#   -> Running method: Functional linear SVM
# Current Fold: rep2_fold2
#   -> Running method: Functional logistic regression (L2)
#   -> Running method: Functional logistic regression (L1)
#   -> Running method: Functional linear SVM
# Current Fold: rep2_fold3
#   -> Running method: Functional logistic regression (L2)
#   -> Running method: Functional logistic regression (L1)
#   -> Running method: Functional linear SVM
# Current Fold: rep2_fold4
#   -> Running method: Functional logistic regression (L2)
#   -> Running method: Functional logistic regression (L1)
#   -> Running method: Functional linear SVM
# Current Fold: rep3_fold0
#   -> Running method: Functional logistic regression (L2)
#   -> Running method: Functional logistic regression (L1)
#   -> Running method: Functional linear SVM
# Current Fold: rep3_fold1
#   -> Running method: Functional logistic regression (L2)
#   -> Running method: Functional logistic regression (L1)
#   -> Running method: Functional linear SVM
# Current Fold: rep3_fold2
#   -> Running method: Functional logistic regression (L2)
#   -> Running method: Functional logistic regression (L1)
#   -> Running method: Functional linear SVM
# Current Fold: rep3_fold3
#   -> Running method: Functional logistic regression (L2)
#   -> Running method: Functional logistic regression (L1)
#   -> Running method: Functional linear SVM
# Current Fold: rep3_fold4
#   -> Running method: Functional logistic regression (L2)
#   -> Running method: Functional logistic regression (L1)
#   -> Running method: Functional linear SVM
# Current Fold: rep4_fold0
#   -> Running method: Functional logistic regression (L2)
#   -> Running method: Functional logistic regression (L1)
#   -> Running method: Functional linear SVM
# Current Fold: rep4_fold1
#   -> Running method: Functional logistic regression (L2)
#   -> Running method: Functional logistic regression (L1)
#   -> Running method: Functional linear SVM
# Current Fold: rep4_fold2
#   -> Running method: Functional logistic regression (L2)
#   -> Running method: Functional logistic regression (L1)
#   -> Running method: Functional linear SVM
# Current Fold: rep4_fold3
#   -> Running method: Functional logistic regression (L2)
#   -> Running method: Functional logistic regression (L1)
#   -> Running method: Functional linear SVM
# Current Fold: rep4_fold4
#   -> Running method: Functional logistic regression (L2)
#   -> Running method: Functional logistic regression (L1)
#   -> Running method: Functional linear SVM
# Current Fold: rep5_fold0
#   -> Running method: Functional logistic regression (L2)
#   -> Running method: Functional logistic regression (L1)
#   -> Running method: Functional linear SVM
# Current Fold: rep5_fold1
#   -> Running method: Functional logistic regression (L2)
#   -> Running method: Functional logistic regression (L1)
#   -> Running method: Functional linear SVM
# Current Fold: rep5_fold2
#   -> Running method: Functional logistic regression (L2)
#   -> Running method: Functional logistic regression (L1)
#   -> Running method: Functional linear SVM
# Current Fold: rep5_fold3
#   -> Running method: Functional logistic regression (L2)
#   -> Running method: Functional logistic regression (L1)
#   -> Running method: Functional linear SVM
# Current Fold: rep5_fold4
#   -> Running method: Functional logistic regression (L2)
#   -> Running method: Functional logistic regression (L1)
#   -> Running method: Functional linear SVM
# Current Fold: rep6_fold0
#   -> Running method: Functional logistic regression (L2)
#   -> Running method: Functional logistic regression (L1)
#   -> Running method: Functional linear SVM
# Current Fold: rep6_fold1
#   -> Running method: Functional logistic regression (L2)
#   -> Running method: Functional logistic regression (L1)
#   -> Running method: Functional linear SVM
# Current Fold: rep6_fold2
#   -> Running method: Functional logistic regression (L2)
#   -> Running method: Functional logistic regression (L1)
#   -> Running method: Functional linear SVM
# Current Fold: rep6_fold3
#   -> Running method: Functional logistic regression (L2)
#   -> Running method: Functional logistic regression (L1)
#   -> Running method: Functional linear SVM
# Current Fold: rep6_fold4
#   -> Running method: Functional logistic regression (L2)
#   -> Running method: Functional logistic regression (L1)
#   -> Running method: Functional linear SVM
# Current Fold: rep7_fold0
#   -> Running method: Functional logistic regression (L2)
#   -> Running method: Functional logistic regression (L1)
#   -> Running method: Functional linear SVM
# Current Fold: rep7_fold1
#   -> Running method: Functional logistic regression (L2)
#   -> Running method: Functional logistic regression (L1)
#   -> Running method: Functional linear SVM
# Current Fold: rep7_fold2
#   -> Running method: Functional logistic regression (L2)
#   -> Running method: Functional logistic regression (L1)
#   -> Running method: Functional linear SVM
# Current Fold: rep7_fold3
#   -> Running method: Functional logistic regression (L2)
#   -> Running method: Functional logistic regression (L1)
#   -> Running method: Functional linear SVM
# Current Fold: rep7_fold4
#   -> Running method: Functional logistic regression (L2)
#   -> Running method: Functional logistic regression (L1)
#   -> Running method: Functional linear SVM
# Current Fold: rep8_fold0
#   -> Running method: Functional logistic regression (L2)
#   -> Running method: Functional logistic regression (L1)
#   -> Running method: Functional linear SVM
# Current Fold: rep8_fold1
#   -> Running method: Functional logistic regression (L2)
#   -> Running method: Functional logistic regression (L1)
#   -> Running method: Functional linear SVM
# Current Fold: rep8_fold2
#   -> Running method: Functional logistic regression (L2)
#   -> Running method: Functional logistic regression (L1)
#   -> Running method: Functional linear SVM
# Current Fold: rep8_fold3
#   -> Running method: Functional logistic regression (L2)
#   -> Running method: Functional logistic regression (L1)
#   -> Running method: Functional linear SVM
# Current Fold: rep8_fold4
#   -> Running method: Functional logistic regression (L2)
#   -> Running method: Functional logistic regression (L1)
#   -> Running method: Functional linear SVM
# Current Fold: rep9_fold0
#   -> Running method: Functional logistic regression (L2)
#   -> Running method: Functional logistic regression (L1)
#   -> Running method: Functional linear SVM
# Current Fold: rep9_fold1
#   -> Running method: Functional logistic regression (L2)
#   -> Running method: Functional logistic regression (L1)
#   -> Running method: Functional linear SVM
# Current Fold: rep9_fold2
#   -> Running method: Functional logistic regression (L2)
#   -> Running method: Functional logistic regression (L1)
#   -> Running method: Functional linear SVM
# Current Fold: rep9_fold3
#   -> Running method: Functional logistic regression (L2)
#   -> Running method: Functional logistic regression (L1)
#   -> Running method: Functional linear SVM
# Current Fold: rep9_fold4
#   -> Running method: Functional logistic regression (L2)
#   -> Running method: Functional logistic regression (L1)
#   -> Running method: Functional linear SVM
#
# Processing complete.
# Linear fold metrics: (150, 15)
# Linear summary: (3, 20)
#               family                               method  pr_auc_mean  \
# 0  Functional linear                Functional linear SVM     0.864106
# 2  Functional linear  Functional logistic regression (L2)     0.861977
# 1  Functional linear  Functional logistic regression (L1)     0.853528
#
#    pr_auc_std  roc_auc_mean  roc_auc_std  sensitivity_mean  sensitivity_std  \
# 0    0.028265      0.915193     0.020547          0.829736         0.032783
# 2    0.028785      0.914110     0.020148          0.830640         0.032684
# 1    0.030217      0.911170     0.019937          0.831535         0.030596
#
#    precision_mean  precision_std  specificity_mean  specificity_std  \
# 0        0.791497       0.038879          0.945458         0.012556
# 2        0.783333       0.036890          0.942799         0.011744
# 1        0.760405       0.052539          0.934074         0.018634
#
#    accuracy_mean  accuracy_std   f1_mean    f1_std  youden_j_mean  \
# 0       0.922522      0.012425  0.809560  0.028574       0.775194
# 2       0.920568      0.012462  0.805820  0.029015       0.773439
# 1       0.913748      0.016347  0.793361  0.034110       0.765609
#
#    youden_j_std  youden_threshold_mean  youden_threshold_std
# 0      0.036079               0.146432              0.020075
# 2      0.036897               0.408643              0.033200
# 1      0.036494               0.441407              0.048576

# %% [markdown]
#   ## 9. Import FPCA / FPLS summary and

# %%
df_fpca_fpls = None

if FILE_FPCA_FPLS_SUMMARY is not None and FILE_FPCA_FPLS_SUMMARY.exists():
    df_fpca_fpls = pd.read_csv(FILE_FPCA_FPLS_SUMMARY).copy()
    print("Loaded FPCA/FPLS summary:", df_fpca_fpls.shape)

# %% [markdown]
#   ## 10. Convert all sources into one common final schema

# %%
final_rows = []

for _, r in df_distance_summary.iterrows():
    final_rows.append({
        "source": "04 rerun",
        "family": r["family"],
        "method": r["method"],
        "representation": "L2-normalised sampled spectra",
        "tuning": f"k={DISTANCE_K}" if "kNN" in r["model_name"] else "class centroids",
        "pr_auc_mean": r["pr_auc_mean"],
        "pr_auc_std": r["pr_auc_std"],
        "roc_auc_mean": r["roc_auc_mean"],
        "roc_auc_std": r["roc_auc_std"],
        "sensitivity_mean": r["sensitivity_mean"],
        "sensitivity_std": r["sensitivity_std"],
        "precision_mean": r["precision_mean"],
        "precision_std": r["precision_std"],
        "specificity_mean": r["specificity_mean"],
        "specificity_std": r["specificity_std"],
        "accuracy_mean": r["accuracy_mean"],
        "accuracy_std": r["accuracy_std"],
        "f1_mean": r["f1_mean"],
        "f1_std": r["f1_std"],
        "youden_j_mean": r["youden_j_mean"],
        "youden_j_std": r["youden_j_std"],
    })

for _, r in df_linear_summary.iterrows():
    sub = df_linear_fold[df_linear_fold["method"] == r["method"]]
    best_c_mean = sub["best_C"].mean()
    tuning = f"inner-CV C | mean best C={best_c_mean:.4g}"

    final_rows.append({
        "source": "04 rerun",
        "family": r["family"],
        "method": r["method"],
        "representation": "L2-normalised sampled spectra",
        "tuning": tuning,
        "pr_auc_mean": r["pr_auc_mean"],
        "pr_auc_std": r["pr_auc_std"],
        "roc_auc_mean": r["roc_auc_mean"],
        "roc_auc_std": r["roc_auc_std"],
        "sensitivity_mean": r["sensitivity_mean"],
        "sensitivity_std": r["sensitivity_std"],
        "precision_mean": r["precision_mean"],
        "precision_std": r["precision_std"],
        "specificity_mean": r["specificity_mean"],
        "specificity_std": r["specificity_std"],
        "accuracy_mean": r["accuracy_mean"],
        "accuracy_std": r["accuracy_std"],
        "f1_mean": r["f1_mean"],
        "f1_std": r["f1_std"],
        "youden_j_mean": r["youden_j_mean"],
        "youden_j_std": r["youden_j_std"],
    })

if df_fpca_fpls is not None:
    df_use = df_fpca_fpls.copy()

    if "method_family" in df_use.columns and "classifier" in df_use.columns:
        df_use["family"] = "FPCA / FPLS"
        df_use["method"] = df_use["method_family"].astype(str) + " + " + df_use["classifier"].astype(str)
        df_use["representation"] = df_use["method_family"].astype(str)
        if "J" in df_use.columns:
            df_use["tuning"] = "J=" + df_use["J"].astype(str)
        else:
            df_use["tuning"] = "imported summary"

        for _, r in df_use.iterrows():
            final_rows.append({
                "source": "09 summary",
                "family": r["family"],
                "method": r["method"],
                "representation": r["representation"],
                "tuning": r["tuning"],
                "pr_auc_mean": r.get("pr_auc_mean", np.nan),
                "pr_auc_std": r.get("pr_auc_std", np.nan),
                "roc_auc_mean": r.get("roc_auc_mean", np.nan),
                "roc_auc_std": r.get("roc_auc_std", np.nan),
                "sensitivity_mean": r.get("sensitivity_mean", np.nan),
                "sensitivity_std": r.get("sensitivity_std", np.nan),
                "precision_mean": r.get("precision_mean", np.nan),
                "precision_std": r.get("precision_std", np.nan),
                "specificity_mean": r.get("specificity_mean", np.nan),
                "specificity_std": r.get("specificity_std", np.nan),
                "accuracy_mean": r.get("accuracy_mean", np.nan),
                "accuracy_std": r.get("accuracy_std", np.nan),
                "f1_mean": r.get("f1_mean", np.nan),
                "f1_std": r.get("f1_std", np.nan),
                "youden_j_mean": r.get("youden_j_mean", np.nan),
                "youden_j_std": r.get("youden_j_std", np.nan),
            })

final_df = pd.DataFrame(final_rows)
print("Final combined rows:", final_df.shape)
# Out:
# Final combined rows: (11, 21)

# %% [markdown]
#   ## 11. Final ranking tables

# %%
rank_by_f1 = final_df.sort_values(
    ["f1_mean", "pr_auc_mean", "roc_auc_mean"],
    ascending=False,
    na_position="last",
).reset_index(drop=True)

rank_by_pr = final_df.sort_values(
    ["pr_auc_mean", "f1_mean", "roc_auc_mean"],
    ascending=False,
    na_position="last",
).reset_index(drop=True)

print("\n=== TOP MODELS BY F1 ===")
print(
    rank_by_f1[
        ["source", "family", "method", "representation", "tuning", "f1_mean", "pr_auc_mean", "roc_auc_mean"]
    ].head(20).to_string(index=False)
)

print("\n=== TOP MODELS BY PR-AUC ===")
print(
    rank_by_pr[
        ["source", "family", "method", "representation", "tuning", "pr_auc_mean", "f1_mean", "roc_auc_mean"]
    ].head(20).to_string(index=False)
)
# Out:
# === TOP MODELS BY F1 ===
#   source                    family                              method                representation                           tuning  f1_mean  pr_auc_mean  roc_auc_mean
# 04 rerun         Functional linear               Functional linear SVM L2-normalised sampled spectra   inner-CV C | mean best C=3.394 0.809560     0.864106      0.915193
# 04 rerun         Functional linear Functional logistic regression (L2) L2-normalised sampled spectra inner-CV C | mean best C=0.01812 0.805820     0.861977      0.914110
# 04 rerun         Functional linear Functional logistic regression (L1) L2-normalised sampled spectra   inner-CV C | mean best C=200.3 0.793361     0.853528      0.911170
# 04 rerun Distance-based functional           weighted kNN + seuclidean L2-normalised sampled spectra                              k=5 0.773768     0.808304      0.891048
# 04 rerun Distance-based functional            weighted kNN + euclidean L2-normalised sampled spectra                              k=5 0.698724     0.736810      0.854622
# 04 rerun Distance-based functional               weighted kNN + cosine L2-normalised sampled spectra                              k=5 0.696108     0.736709      0.854638
# 04 rerun Distance-based functional               centroid + seuclidean L2-normalised sampled spectra                  class centroids 0.550740     0.573751      0.799785
# 04 rerun Distance-based functional                   centroid + cosine L2-normalised sampled spectra                  class centroids 0.511395     0.539304      0.777023
# 04 rerun Distance-based functional                centroid + euclidean L2-normalised sampled spectra                  class centroids 0.510830     0.540099      0.777215
# 04 rerun Distance-based functional          weighted kNN + correlation L2-normalised sampled spectra                              k=5 0.499961     0.545041      0.728922
# 04 rerun Distance-based functional              centroid + correlation L2-normalised sampled spectra                  class centroids 0.398912     0.372718      0.677382
#
# === TOP MODELS BY PR-AUC ===
#   source                    family                              method                representation                           tuning  pr_auc_mean  f1_mean  roc_auc_mean
# 04 rerun         Functional linear               Functional linear SVM L2-normalised sampled spectra   inner-CV C | mean best C=3.394     0.864106 0.809560      0.915193
# 04 rerun         Functional linear Functional logistic regression (L2) L2-normalised sampled spectra inner-CV C | mean best C=0.01812     0.861977 0.805820      0.914110
# 04 rerun         Functional linear Functional logistic regression (L1) L2-normalised sampled spectra   inner-CV C | mean best C=200.3     0.853528 0.793361      0.911170
# 04 rerun Distance-based functional           weighted kNN + seuclidean L2-normalised sampled spectra                              k=5     0.808304 0.773768      0.891048
# 04 rerun Distance-based functional            weighted kNN + euclidean L2-normalised sampled spectra                              k=5     0.736810 0.698724      0.854622
# 04 rerun Distance-based functional               weighted kNN + cosine L2-normalised sampled spectra                              k=5     0.736709 0.696108      0.854638
# 04 rerun Distance-based functional               centroid + seuclidean L2-normalised sampled spectra                  class centroids     0.573751 0.550740      0.799785
# 04 rerun Distance-based functional          weighted kNN + correlation L2-normalised sampled spectra                              k=5     0.545041 0.499961      0.728922
# 04 rerun Distance-based functional                centroid + euclidean L2-normalised sampled spectra                  class centroids     0.540099 0.510830      0.777215
# 04 rerun Distance-based functional                   centroid + cosine L2-normalised sampled spectra                  class centroids     0.539304 0.511395      0.777023
# 04 rerun Distance-based functional              centroid + correlation L2-normalised sampled spectra                  class centroids     0.372718 0.398912      0.677382

# %% [markdown]
#   ## 12. Pretty final comparison table

# %%
pretty_table = pd.DataFrame({
    "Source": rank_by_f1["source"],
    "Family": rank_by_f1["family"],
    "Method": rank_by_f1["method"],
    "Representation": rank_by_f1["representation"],
    "Tuning": rank_by_f1["tuning"],
    "PR-AUC mean ± std": [ms(m, s) for m, s in zip(rank_by_f1["pr_auc_mean"], rank_by_f1["pr_auc_std"])],
    "ROC-AUC mean ± std": [ms(m, s) for m, s in zip(rank_by_f1["roc_auc_mean"], rank_by_f1["roc_auc_std"])],
    "Sensitivity mean ± std": [ms(m, s) for m, s in zip(rank_by_f1["sensitivity_mean"], rank_by_f1["sensitivity_std"])],
    "Precision mean ± std": [ms(m, s) for m, s in zip(rank_by_f1["precision_mean"], rank_by_f1["precision_std"])],
    "Specificity mean ± std": [ms(m, s) for m, s in zip(rank_by_f1["specificity_mean"], rank_by_f1["specificity_std"])],
    "Accuracy mean ± std": [ms(m, s) for m, s in zip(rank_by_f1["accuracy_mean"], rank_by_f1["accuracy_std"])],
    "F1 mean ± std": [ms(m, s) for m, s in zip(rank_by_f1["f1_mean"], rank_by_f1["f1_std"])],
    "Youden J mean ± std": [ms(m, s) for m, s in zip(rank_by_f1["youden_j_mean"], rank_by_f1["youden_j_std"])],
})

print("\n=== FINAL COMPARISON TABLE ===")
print(pretty_table.head(20).to_string(index=False))
# Out:
# === FINAL COMPARISON TABLE ===
#   Source                    Family                              Method                Representation                           Tuning PR-AUC mean ± std ROC-AUC mean ± std Sensitivity mean ± std Precision mean ± std Specificity mean ± std Accuracy mean ± std   F1 mean ± std Youden J mean ± std
# 04 rerun         Functional linear               Functional linear SVM L2-normalised sampled spectra   inner-CV C | mean best C=3.394   0.8641 ± 0.0283    0.9152 ± 0.0205        0.8297 ± 0.0328      0.7915 ± 0.0389        0.9455 ± 0.0126     0.9225 ± 0.0124 0.8096 ± 0.0286     0.7752 ± 0.0361
# 04 rerun         Functional linear Functional logistic regression (L2) L2-normalised sampled spectra inner-CV C | mean best C=0.01812   0.8620 ± 0.0288    0.9141 ± 0.0201        0.8306 ± 0.0327      0.7833 ± 0.0369        0.9428 ± 0.0117     0.9206 ± 0.0125 0.8058 ± 0.0290     0.7734 ± 0.0369
# 04 rerun         Functional linear Functional logistic regression (L1) L2-normalised sampled spectra   inner-CV C | mean best C=200.3   0.8535 ± 0.0302    0.9112 ± 0.0199        0.8315 ± 0.0306      0.7604 ± 0.0525        0.9341 ± 0.0186     0.9137 ± 0.0163 0.7934 ± 0.0341     0.7656 ± 0.0365
# 04 rerun Distance-based functional           weighted kNN + seuclidean L2-normalised sampled spectra                              k=5   0.8083 ± 0.0354    0.8910 ± 0.0201        0.7765 ± 0.0402      0.7736 ± 0.0432        0.9429 ± 0.0145     0.9099 ± 0.0118 0.7738 ± 0.0274     0.7194 ± 0.0380
# 04 rerun Distance-based functional            weighted kNN + euclidean L2-normalised sampled spectra                              k=5   0.7368 ± 0.0406    0.8546 ± 0.0244        0.6855 ± 0.0414      0.7154 ± 0.0488        0.9315 ± 0.0166     0.8827 ± 0.0140 0.6987 ± 0.0319     0.6170 ± 0.0411
# 04 rerun Distance-based functional               weighted kNN + cosine L2-normalised sampled spectra                              k=5   0.7367 ± 0.0405    0.8546 ± 0.0244        0.6858 ± 0.0424      0.7100 ± 0.0500        0.9295 ± 0.0184     0.8812 ± 0.0146 0.6961 ± 0.0314     0.6153 ± 0.0406
# 04 rerun Distance-based functional               centroid + seuclidean L2-normalised sampled spectra                  class centroids   0.5738 ± 0.0412    0.7998 ± 0.0247        0.7348 ± 0.0372      0.4411 ± 0.0286        0.7687 ± 0.0244     0.7620 ± 0.0206 0.5507 ± 0.0281     0.5035 ± 0.0437
# 04 rerun Distance-based functional                   centroid + cosine L2-normalised sampled spectra                  class centroids   0.5393 ± 0.0438    0.7770 ± 0.0255        0.7208 ± 0.0362      0.3968 ± 0.0265        0.7279 ± 0.0259     0.7265 ± 0.0221 0.5114 ± 0.0273     0.4487 ± 0.0449
# 04 rerun Distance-based functional                centroid + euclidean L2-normalised sampled spectra                  class centroids   0.5401 ± 0.0438    0.7772 ± 0.0256        0.7197 ± 0.0366      0.3965 ± 0.0267        0.7279 ± 0.0260     0.7263 ± 0.0223 0.5108 ± 0.0276     0.4476 ± 0.0454
# 04 rerun Distance-based functional          weighted kNN + correlation L2-normalised sampled spectra                              k=5   0.5450 ± 0.0438    0.7289 ± 0.0244        0.4846 ± 0.0602      0.5246 ± 0.0608        0.8870 ± 0.0453     0.8072 ± 0.0311 0.5000 ± 0.0416     0.3716 ± 0.0506
# 04 rerun Distance-based functional              centroid + correlation L2-normalised sampled spectra                  class centroids   0.3727 ± 0.0444    0.6774 ± 0.0312        0.7093 ± 0.0464      0.2780 ± 0.0165        0.5429 ± 0.0416     0.5758 ± 0.0295 0.3989 ± 0.0194     0.2522 ± 0.0425

# %% [markdown]
#   ## 13. Best method within each family

# %%
best_by_family = (
    final_df.sort_values(["f1_mean", "pr_auc_mean"], ascending=False, na_position="last")
    .groupby("family", as_index=False)
    .first()
)

best_by_family_pretty = pd.DataFrame({
    "Family": best_by_family["family"],
    "Method": best_by_family["method"],
    "Representation": best_by_family["representation"],
    "Tuning": best_by_family["tuning"],
    "PR-AUC mean ± std": [ms(m, s) for m, s in zip(best_by_family["pr_auc_mean"], best_by_family["pr_auc_std"])],
    "ROC-AUC mean ± std": [ms(m, s) for m, s in zip(best_by_family["roc_auc_mean"], best_by_family["roc_auc_std"])],
    "F1 mean ± std": [ms(m, s) for m, s in zip(best_by_family["f1_mean"], best_by_family["f1_std"])],
})

print("\n=== BEST BY FAMILY ===")
print(best_by_family_pretty.to_string(index=False))
# Out:
# === BEST BY FAMILY ===
#                    Family                    Method                Representation                         Tuning PR-AUC mean ± std ROC-AUC mean ± std   F1 mean ± std
# Distance-based functional weighted kNN + seuclidean L2-normalised sampled spectra                            k=5   0.8083 ± 0.0354    0.8910 ± 0.0201 0.7738 ± 0.0274
#         Functional linear     Functional linear SVM L2-normalised sampled spectra inner-CV C | mean best C=3.394   0.8641 ± 0.0283    0.9152 ± 0.0205 0.8096 ± 0.0286

# %% [markdown]
#   ## 14. Basic diagnostic plots for the final comparison

# %%
trade_df = rank_by_f1.dropna(subset=["specificity_mean", "sensitivity_mean"]).head(15).copy()

plt.figure(figsize=(7, 5))
plt.scatter(trade_df["specificity_mean"], trade_df["sensitivity_mean"])
for _, r in trade_df.iterrows():
    plt.annotate(r["method"], (r["specificity_mean"], r["sensitivity_mean"]), fontsize=8)
plt.xlabel("Specificity")
plt.ylabel("Sensitivity")
plt.title("Sensitivity vs Specificity")
plt.tight_layout()
plt.savefig(OUT_DIR / f"{NOTEBOOK_NAME}_sens_vs_spec_{TIMESTAMP}.png", dpi=200)
plt.show()
plt.close()

# %%
scatter_df = rank_by_f1.dropna(subset=["pr_auc_mean", "f1_mean"]).head(20).copy()

plt.figure(figsize=(7, 5))
plt.scatter(scatter_df["pr_auc_mean"], scatter_df["f1_mean"])
for _, r in scatter_df.iterrows():
    plt.annotate(r["method"], (r["pr_auc_mean"], r["f1_mean"]), fontsize=8)
plt.xlabel("PR-AUC")
plt.ylabel("F1")
plt.title("F1 vs PR-AUC")
plt.tight_layout()
plt.savefig(OUT_DIR / f"{NOTEBOOK_NAME}_f1_vs_pr_auc_{TIMESTAMP}.png", dpi=200)
plt.show()
plt.close()

# %% [markdown]
#   ## 15. Build and save interpretability payload for notebook 06
#
#
#
#   No interpretability figures are produced here.
#
#   This section only prepares and stores all arrays needed by notebook 06.

# %%
mean_0 = X[y == 0].mean(axis=0)
mean_1 = X[y == 1].mean(axis=0)
diff_10 = mean_1 - mean_0

pca = PCA(n_components=2, random_state=RANDOM_STATE)
scores_fpca = pca.fit_transform(X)

pls = PLSRegression(n_components=2)
scores_fpls, _ = pls.fit_transform(X, y.astype(float).reshape(-1, 1))

first_split = split_names[0]
tr_idx = np.array(splits[first_split]["train"], dtype=int)
te_idx = np.array(splits[first_split]["test"], dtype=int)

X_tr = X[tr_idx]
X_te = X[te_idx]
y_tr = y[tr_idx]
y_te = y[te_idx]

test_pos = np.where(y_te == 1)[0]
example_te_local = int(test_pos[0]) if len(test_pos) else 0
x_query = X_te[example_te_local:example_te_local + 1]

D = pairwise_distances(x_query, X_tr, metric="euclidean").ravel()
nn_idx = np.argsort(D)[:DISTANCE_K]
nn_labels = y_tr[nn_idx]
nn_dists = D[nn_idx]

nn_table = pd.DataFrame({
    "train_index_local": nn_idx,
    "distance": nn_dists,
    "label": nn_labels,
})

closest_idx = int(nn_idx[0])
closest_curve = X_tr[closest_idx]
abs_diff = np.abs(x_query.ravel() - closest_curve)

scaler_full = StandardScaler()
X_full_s = scaler_full.fit_transform(X)

logreg_full = LogisticRegression(
    C=float(df_linear_fold.loc[
        df_linear_fold["method"] == "Functional logistic regression (L2)", "best_C"
    ].median()),
    penalty="l2",
    solver="lbfgs",
    class_weight="balanced",
    max_iter=4000,
    random_state=RANDOM_STATE,
)
logreg_full.fit(X_full_s, y)
beta_logreg = logreg_full.coef_[0].copy()

svm_full = LinearSVC(
    C=float(df_linear_fold.loc[
        df_linear_fold["method"] == "Functional linear SVM", "best_C"
    ].median()),
    class_weight="balanced",
    max_iter=10000,
    random_state=RANDOM_STATE,
)
svm_full.fit(X_full_s, y)
beta_svm = svm_full.coef_[0].copy()

interpretability_payload_path = OUT_DIR / f"{NOTEBOOK_NAME}_interpretability_payload_{TIMESTAMP}.npz"
nearest_neighbour_table_path = OUT_DIR / f"{NOTEBOOK_NAME}_nearest_neighbour_table_{TIMESTAMP}.csv"

np.savez(
    interpretability_payload_path,
    wavelengths=wavelengths,
    y=y,
    mean_0=mean_0,
    mean_1=mean_1,
    diff_10=diff_10,
    scores_fpca=scores_fpca,
    scores_fpls=scores_fpls,
    x_query=x_query.ravel(),
    closest_curve=closest_curve,
    abs_diff=abs_diff,
    beta_logreg=beta_logreg,
    beta_svm=beta_svm,
)

nn_table.to_csv(nearest_neighbour_table_path, index=False)

print("Interpretability payload saved:")
print("-", interpretability_payload_path)
print("-", nearest_neighbour_table_path)
# Out:
# Interpretability payload saved:
# - c:\Users\Lenovo\Documents\VDA\Bakalauras\astroflow_project\results\final_functional\04_final_functional_interpretability_payload_20260410_1655.npz
# - c:\Users\Lenovo\Documents\VDA\Bakalauras\astroflow_project\results\final_functional\04_final_functional_nearest_neighbour_table_20260410_1655.csv

# %% [markdown]
#   ## 16. Save main tables and summaries

# %%
distance_fold_path = OUT_DIR / f"{NOTEBOOK_NAME}_distance_fold_metrics_{TIMESTAMP}.csv"
distance_summary_path = OUT_DIR / f"{NOTEBOOK_NAME}_distance_summary_{TIMESTAMP}.csv"
linear_fold_path = OUT_DIR / f"{NOTEBOOK_NAME}_linear_fold_metrics_{TIMESTAMP}.csv"
linear_summary_path = OUT_DIR / f"{NOTEBOOK_NAME}_linear_summary_{TIMESTAMP}.csv"

final_df_path = OUT_DIR / f"{NOTEBOOK_NAME}_final_df_{TIMESTAMP}.csv"
rank_f1_path = OUT_DIR / f"{NOTEBOOK_NAME}_rank_by_f1_{TIMESTAMP}.csv"
rank_pr_path = OUT_DIR / f"{NOTEBOOK_NAME}_rank_by_pr_auc_{TIMESTAMP}.csv"
pretty_path = OUT_DIR / f"{NOTEBOOK_NAME}_pretty_table_{TIMESTAMP}.csv"
best_family_path = OUT_DIR / f"{NOTEBOOK_NAME}_best_by_family_{TIMESTAMP}.csv"

df_distance_fold.to_csv(distance_fold_path, index=False)
df_distance_summary.to_csv(distance_summary_path, index=False)
df_linear_fold.to_csv(linear_fold_path, index=False)
df_linear_summary.to_csv(linear_summary_path, index=False)

final_df.to_csv(final_df_path, index=False)
rank_by_f1.to_csv(rank_f1_path, index=False)
rank_by_pr.to_csv(rank_pr_path, index=False)
pretty_table.to_csv(pretty_path, index=False)
best_by_family_pretty.to_csv(best_family_path, index=False)

print("Saved:")
print("-", distance_fold_path)
print("-", distance_summary_path)
print("-", linear_fold_path)
print("-", linear_summary_path)
print("-", final_df_path)
print("-", rank_f1_path)
print("-", rank_pr_path)
print("-", pretty_path)
print("-", best_family_path)
# Out:
# Saved:
# - c:\Users\Lenovo\Documents\VDA\Bakalauras\astroflow_project\results\final_functional\04_final_functional_distance_fold_metrics_20260410_1655.csv
# - c:\Users\Lenovo\Documents\VDA\Bakalauras\astroflow_project\results\final_functional\04_final_functional_distance_summary_20260410_1655.csv
# - c:\Users\Lenovo\Documents\VDA\Bakalauras\astroflow_project\results\final_functional\04_final_functional_linear_fold_metrics_20260410_1655.csv
# - c:\Users\Lenovo\Documents\VDA\Bakalauras\astroflow_project\results\final_functional\04_final_functional_linear_summary_20260410_1655.csv
# - c:\Users\Lenovo\Documents\VDA\Bakalauras\astroflow_project\results\final_functional\04_final_functional_final_df_20260410_1655.csv
# - c:\Users\Lenovo\Documents\VDA\Bakalauras\astroflow_project\results\final_functional\04_final_functional_rank_by_f1_20260410_1655.csv
# - c:\Users\Lenovo\Documents\VDA\Bakalauras\astroflow_project\results\final_functional\04_final_functional_rank_by_pr_auc_20260410_1655.csv
# - c:\Users\Lenovo\Documents\VDA\Bakalauras\astroflow_project\results\final_functional\04_final_functional_pretty_table_20260410_1655.csv
# - c:\Users\Lenovo\Documents\VDA\Bakalauras\astroflow_project\results\final_functional\04_final_functional_best_by_family_20260410_1655.csv

# %% [markdown]
#   ## 17. Short final view

# %%
print("\n=== FINAL TOP 15 BY F1 ===")
print(
    rank_by_f1[
        ["family", "method", "representation", "tuning", "f1_mean", "pr_auc_mean", "roc_auc_mean"]
    ].head(15).to_string(index=False)
)

print("\n=== BEST BY FAMILY ===")
print(best_by_family_pretty.to_string(index=False))
# Out:
# === FINAL TOP 15 BY F1 ===
#                    family                              method                representation                           tuning  f1_mean  pr_auc_mean  roc_auc_mean
#         Functional linear               Functional linear SVM L2-normalised sampled spectra   inner-CV C | mean best C=3.394 0.809560     0.864106      0.915193
#         Functional linear Functional logistic regression (L2) L2-normalised sampled spectra inner-CV C | mean best C=0.01812 0.805820     0.861977      0.914110
#         Functional linear Functional logistic regression (L1) L2-normalised sampled spectra   inner-CV C | mean best C=200.3 0.793361     0.853528      0.911170
# Distance-based functional           weighted kNN + seuclidean L2-normalised sampled spectra                              k=5 0.773768     0.808304      0.891048
# Distance-based functional            weighted kNN + euclidean L2-normalised sampled spectra                              k=5 0.698724     0.736810      0.854622
# Distance-based functional               weighted kNN + cosine L2-normalised sampled spectra                              k=5 0.696108     0.736709      0.854638
# Distance-based functional               centroid + seuclidean L2-normalised sampled spectra                  class centroids 0.550740     0.573751      0.799785
# Distance-based functional                   centroid + cosine L2-normalised sampled spectra                  class centroids 0.511395     0.539304      0.777023
# Distance-based functional                centroid + euclidean L2-normalised sampled spectra                  class centroids 0.510830     0.540099      0.777215
# Distance-based functional          weighted kNN + correlation L2-normalised sampled spectra                              k=5 0.499961     0.545041      0.728922
# Distance-based functional              centroid + correlation L2-normalised sampled spectra                  class centroids 0.398912     0.372718      0.677382
#
# === BEST BY FAMILY ===
#                    Family                    Method                Representation                         Tuning PR-AUC mean ± std ROC-AUC mean ± std   F1 mean ± std
# Distance-based functional weighted kNN + seuclidean L2-normalised sampled spectra                            k=5   0.8083 ± 0.0354    0.8910 ± 0.0201 0.7738 ± 0.0274
#         Functional linear     Functional linear SVM L2-normalised sampled spectra inner-CV C | mean best C=3.394   0.8641 ± 0.0283    0.9152 ± 0.0205 0.8096 ± 0.0286
